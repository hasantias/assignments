# %%
Name = 'Abu Hossain Mohammad Abed Hasan Tias'
ID = '21301295'
Section = '01'

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
from numpy.polynomial import polynomial

# %%
#part a
coeff = [2, 0, 0, 3, 0, 0, 7, 2]
degree = len(coeff)-1
#part b
coeff = [2, 0, 0, 3, 0, 0, 7, 2]
p = None
for i in range(len(coeff)):
  p += coeff[i]*x**i
display(p)
#part c
x = 1.3
p_x = p(x)
#part d
third_derivative = p.deriv(3)
print('third derivative:', third_derivative)
#part e
x = 1.3
third_derivative_x = p(x).deriv(3)
print('Third derivative at x =1.3:', third_derivative_x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-0f1a1a492341> in <cell line: 6>()
#       4 #part b
#       5 coeff = [2, 0, 0, 3, 0, 0, 7, 2]
# ----> 6 p = polynomial(coeff)
#       7 for i in range(len(coeff)):
#       8   p += coeff[i]*x**i
#
# TypeError: 'module' object is not callable

# %%
data_x = [1, 3, 5, 11]
data_y = [1.2, 3.6, 6, 13.2]

def func(x):
  val = 0
  for i in range(len(data_x)):
    val += ((data_x[i]*data_y[i])/(x-data_x[i]))
  return val

# %%
print(func(5))

# %%
data_x = [1, 3, 5, 11]
m = np.zeros(len(data_x), list)
for i in range(len(data_x)):
  for j in range(len(data_x)):
    m[i][j] = data_x**(len(data_x)-j)

print(m)
